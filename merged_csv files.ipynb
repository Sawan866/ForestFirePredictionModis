# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import dataset
df_modis_india = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_india_modis_files.csv')

# %%
df_viirs_india = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_india_viirs_files.csv', low_memory = False)

# %%
df_viirs_india.head()
# Out:
#     latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  10.413700  79.311340      337.54  0.36   0.58  2012-01-20       724
# 1   8.299952  77.602364      333.40  0.52   0.67  2012-01-20       724
# 2  10.670471  78.505699      331.51  0.41   0.61  2012-01-20       724
# 3  14.029049  77.469177      330.11  0.42   0.61  2012-01-20       725
# 4  14.518503  77.913017      331.53  0.38   0.59  2012-01-20       725
#
#   satellite instrument confidence  version  bright_ti5   frp daynight  type
# 0         N      VIIRS          n        1      300.05  1.52        D     0
# 1         N      VIIRS          n        1      295.45  4.67        D     0
# 2         N      VIIRS          n        1      300.57  1.14        D     0
# 3         N      VIIRS          l        1      304.58  1.39        D     0
# 4         N      VIIRS          l        1      304.08  1.05        D     0

# %%
df_viirs_india.columns
# Out:
# Index(['latitude', 'longitude', 'bright_ti4', 'scan', 'track', 'acq_date',
#        'acq_time', 'satellite', 'instrument', 'confidence', 'version',
#        'bright_ti5', 'frp', 'daynight', 'type'],
#       dtype='object')

# %%
df_viirs_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5778777 entries, 0 to 5778776
# Data columns (total 15 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   latitude    float64
#  1   longitude   float64
#  2   bright_ti4  float64
#  3   scan        float64
#  4   track       float64
#  5   acq_date    object
#  6   acq_time    int64
#  7   satellite   object
#  8   instrument  object
#  9   confidence  object
#  10  version     int64
#  11  bright_ti5  float64
#  12  frp         float64
#  13  daynight    object
#  14  type        int64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 661.3+ MB

# %%
df_viirs_india.describe()
# Out:
#            latitude     longitude    bright_ti4          scan         track  \
# count  5.778777e+06  5.778777e+06  5.778777e+06  5.778777e+06  5.778777e+06
# mean   2.341727e+01  8.081430e+01  3.320653e+02  4.519089e-01  4.671032e-01
# std    5.012594e+00  5.735963e+00  1.700984e+01  8.075348e-02  1.079564e-01
# min    6.802476e+00  6.850462e+01  2.080000e+02  3.200000e-01  3.600000e-01
# 25%    1.992545e+01  7.617314e+01  3.191300e+02  3.900000e-01  3.700000e-01
# 50%    2.312531e+01  7.982877e+01  3.358700e+02  4.300000e-01  4.300000e-01
# 75%    2.727923e+01  8.389925e+01  3.428900e+02  5.000000e-01  5.400000e-01
# max    3.476062e+01  9.720400e+01  3.670000e+02  8.000000e-01  7.800000e-01
#
#            acq_time    version    bright_ti5           frp          type
# count  5.778777e+06  5778777.0  5.778777e+06  5.778777e+06  5.778777e+06
# mean   1.111596e+03        1.0  3.014896e+02  6.525188e+00  2.553578e-01
# ...

# %%
df_viirs_india.isnull().sum() # missing value check
# Out:
# latitude      0
# longitude     0
# bright_ti4    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_ti5    0
# frp           0
# daynight      0
# type          0
# dtype: int64

# %%
sns.heatmap(df_viirs_india.isnull(), yticklabels= False, cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df_viirs_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5778777 entries, 0 to 5778776
# Data columns (total 15 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   latitude    float64
#  1   longitude   float64
#  2   bright_ti4  float64
#  3   scan        float64
#  4   track       float64
#  5   acq_date    object
#  6   acq_time    int64
#  7   satellite   object
#  8   instrument  object
#  9   confidence  object
#  10  version     int64
#  11  bright_ti5  float64
#  12  frp         float64
#  13  daynight    object
#  14  type        int64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 661.3+ MB

# %%
df_merged = pd.concat([df_modis_india,df_viirs_india],sort=True)
data = df_merged
data.head()
# Out:
#      acq_date  acq_time  bright_t31  bright_ti4  bright_ti5  brightness  \
# 0  2000-11-01       501       303.3         NaN         NaN       318.9
# 1  2000-11-01       501       299.4         NaN         NaN       326.4
# 2  2000-11-01       501       299.1         NaN         NaN       320.7
# 3  2000-11-01       501       298.5         NaN         NaN       319.7
# 4  2000-11-01       503       298.3         NaN         NaN       315.9
#
#   confidence daynight   frp instrument  latitude  longitude satellite  scan  \
# 0         67        D  12.1      MODIS   23.6805    86.0949     Terra   1.2
# 1         54        D  19.8      MODIS   22.7913    86.2102     Terra   1.2
# 2         65        D  15.0      MODIS   22.7885    86.2037     Terra   1.2
# 3         66        D  13.8      MODIS   22.7870    86.2150     Terra   1.2
# 4         18        D  28.8      MODIS   18.7651    79.9640     Terra   2.7
#
#    track  type  version
# 0    1.1     2      6.2
# 1    1.1     0      6.2
# ...

# %%
data.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_india.csv', index=False)

# %%
df_viirs_nepal = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_nepal_viirs_files.csv')
df_viirs_nepal.head()
# Out:
#     latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  26.650742  86.959084      333.02  0.42   0.38  2012-01-20       728
# 1  26.621929  86.981117      325.71  0.42   0.38  2012-01-20       728
# 2  26.625381  86.980537      340.33  0.42   0.38  2012-01-20       728
# 3  26.648424  86.968094      330.45  0.42   0.38  2012-01-20       728
# 4  26.647289  86.959663      325.98  0.42   0.38  2012-01-20       728
#
#   satellite instrument confidence  version  bright_ti5   frp daynight  type
# 0         N      VIIRS          n        1      295.28  4.08        D     0
# 1         N      VIIRS          n        1      295.49  7.35        D     0
# 2         N      VIIRS          n        1      296.81  7.35        D     0
# 3         N      VIIRS          n        1      296.76  2.07        D     0
# 4         N      VIIRS          n        1      295.20  4.08        D     0

# %%
df_modis_nepal = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_nepal_modis_files.csv')
df_modis_nepal.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   27.5921    87.5385       306.2   1.1    1.1  2000-11-01       500
# 1   29.1006    81.9170       330.6   1.3    1.1  2000-11-06       518
# 2   30.0881    81.3358       308.7   1.8    1.3  2000-11-07       601
# 3   30.0841    81.3570       306.0   1.9    1.3  2000-11-07       601
# 4   30.1060    81.9647       315.0   2.1    1.4  2000-11-08       506
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          55      6.2       292.1   6.2        D     0
# 1     Terra      MODIS          87      6.2       293.7  43.0        D     0
# 2     Terra      MODIS          58      6.2       291.2  21.1        D     0
# 3     Terra      MODIS          37      6.2       287.4  17.1        D     0
# 4     Terra      MODIS          64      6.2       282.6  41.6        D     0

# %%
df_merged1 = pd.concat([df_modis_nepal,df_viirs_nepal],sort=True)
data1 = df_merged1
data1.head()
# Out:
#      acq_date  acq_time  bright_t31  bright_ti4  bright_ti5  brightness  \
# 0  2000-11-01       500       292.1         NaN         NaN       306.2
# 1  2000-11-06       518       293.7         NaN         NaN       330.6
# 2  2000-11-07       601       291.2         NaN         NaN       308.7
# 3  2000-11-07       601       287.4         NaN         NaN       306.0
# 4  2000-11-08       506       282.6         NaN         NaN       315.0
#
#   confidence daynight   frp instrument  latitude  longitude satellite  scan  \
# 0         55        D   6.2      MODIS   27.5921    87.5385     Terra   1.1
# 1         87        D  43.0      MODIS   29.1006    81.9170     Terra   1.3
# 2         58        D  21.1      MODIS   30.0881    81.3358     Terra   1.8
# 3         37        D  17.1      MODIS   30.0841    81.3570     Terra   1.9
# 4         64        D  41.6      MODIS   30.1060    81.9647     Terra   2.1
#
#    track  type  version
# 0    1.1     0      6.2
# 1    1.1     0      6.2
# ...

# %%
data1.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/Dataset/merged_nepal.csv', index=False)
